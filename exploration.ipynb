# %%
import pickle
import pandas as pd
from light_curve import LightCurve
import matplotlib.pyplot as plt

# %%
import joblib
path_macho = '/Users/francisco/Documents/data/macho/full.pkl'

data_macho = joblib.load(path_macho)

# %%
data_macho[1].__dict__
# Out:
# {'times': array([48823.7738, 48824.8011, 48825.8012, 48828.7732, 48829.7409,
#         48831.7202, 48832.718 , 48834.7568, 48835.6461, 48835.793 ,
#         48836.7447, 48841.7331, 48842.7671, 48843.7129, 48851.7417,
#         48854.6589, 48855.806 , 48856.6918, 48884.7274, 48885.6886,
#         48887.7959, 48888.7986, 48908.5466, 48915.6714, 48916.765 ,
#         48917.6187, 48919.6179, 48927.5592, 48928.5987, 48929.5372,
#         48931.5468, 48935.7217, 48937.7461, 48938.5987, 48939.6038,
#         48941.6478, 48947.6922, 48948.7225, 48948.7327, 48949.585 ,
#         48965.5755, 48966.5703, 48985.5981, 48987.5945, 48988.5875,
#         48989.5883, 48996.5381, 48998.5413, 49000.5558, 49001.5495,
#         49001.7432, 49004.4268, 49006.5452, 49014.7333, 49015.5437,
#         49015.6609, 49016.6974, 49018.5373, 49018.6996, 49020.6438,
#         49021.515 , 49021.6811, 49025.6637, 49029.5103, 49032.5049,
#         49037.5059, 49043.6322, 49044.7027, 49045.6348, 49048.6335,
# ...

# %%
data_macho_dict = {}
for i  in

# %%
plt.plot(data_macho[1].times,data_macho[1].measurements,'r+')

# %%
data_macho[1].label
# Out:
# 'RRL AB'

# %%
data_macho[1].period_fold()
plt.plot(data_macho[1].times,data_macho[1].measurements, 'r+')

# %%
path_asas = '/Users/francisco/Documents/data/asas/full.pkl'
data_asas = joblib.load(path_asas)

# %%
plt.plot(data_asas[1].times,data_asas[1].measurements,'r+')

# %%
data_asas[1].period_fold()
plt.plot(data_asas[1].times,data_asas[1].measurements,'r+')

# %%
path_linear = '/Users/francisco/Documents/data/linear/full.pkl'
data_linear = joblib.load(path_linear)

# %%
k=20
plt.plot(data_linear[k].times,data_linear[k].measurements,'r+')

# %%
data_linear[k].period_fold()
plt.plot(data_linear[k].times,data_linear[k].measurements,'r+')
